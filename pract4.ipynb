# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
from scipy import stats

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
plt.bar(x=df['day'], height=df['total_bill'], color='blue', alpha=0.4)
# Out:
# <BarContainer object of 244 artists>

# %%
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
exp=(0.1,0,0,0)
wp={'linewidth': 2, 'edgecolor': "green"}
plt.pie(df['day'].value_counts(), labels=['Sat', 'Sun', 'Thurs', 'Fri'],
        explode=exp, radius=1, colors=colors,
        autopct='%1.3f%%', shadow=True, 
        startangle=90, wedgeprops=wp)
# Out:
# ([<matplotlib.patches.Wedge at 0x219801f9810>,
#   <matplotlib.patches.Wedge at 0x219801f9750>,
#   <matplotlib.patches.Wedge at 0x219801fac80>,
#   <matplotlib.patches.Wedge at 0x219801fb6d0>],
#  [Text(-1.0802031852377976, 0.5226481403412017, 'Sat'),
#   Text(0.08489314165475842, -1.0967192687739125, 'Sun'),
#   Text(1.056165074622452, 0.3074334645866494, 'Thurs'),
#   Text(0.2664196365703863, 1.0672490699221544, 'Fri')],
#  [Text(-0.6301185247220485, 0.304878081865701, '35.656%'),
#   Text(0.04630534999350459, -0.5982105102403158, '31.148%'),
#   Text(0.5760900407031556, 0.16769098068362692, '25.410%'),
#   Text(0.14531980176566525, 0.582135856321175, '7.787%')])

# %%
plt.scatter(x='total_bill', y='tip', c="pink",
            linewidths=0.5,
            marker=".",
            edgecolors="green",
            s=50,
            data=df
            )

# %%
sns.boxplot(x='tip',y='sex',hue='time',orient='h',data=df,showmeans=True)
# Out:
# <Axes: xlabel='tip', ylabel='sex'>

# %%
sns.swarmplot(x="day",y="total_bill", data = df, size=5, palette='Set1')

plt.subplot(1,2,2)
sns.stripplot(x="day", y="total_bill", data = df, size=5, palette='Set1')
plt.show()
# Out:
# C:\Users\kunal\AppData\Local\Temp\ipykernel_9892\3969153923.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x="day",y="total_bill", data = df, size=5, palette='Set1')
# C:\Users\kunal\AppData\Local\Temp\ipykernel_9892\3969153923.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x="day", y="total_bill", data = df, size=5, palette='Set1')

# %%
data =sns.load_dataset('penguins')

# %%
sns.jointplot(x='body_mass_g', y='flipper_length_mm', data=data, kind='hex')

# %%
sns.jointplot(x='body_mass_g', y='flipper_length_mm', data=data, kind='scatter')

# %%
sns.jointplot(x='body_mass_g', y='flipper_length_mm', data=data, kind='reg')

# %%
sns.set(style='ticks')
sns.relplot(x='bill_length_mm', y='bill_depth_mm', data=data)

# %%
sns.relplot(x='bill_length_mm', y='bill_depth_mm', hue='flipper_length_mm', data=data)
